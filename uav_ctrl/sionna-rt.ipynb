# %% [markdown]
# # Imports

# %%
import os # Configure which GPU
if os.getenv("CUDA_VISIBLE_DEVICES") is None:
    gpu_num = 0 # Use "" to use the CPU
    os.environ["CUDA_VISIBLE_DEVICES"] = f"{gpu_num}"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# Import or install Sionna
try:
    import sionna.phy
    import sionna.rt
except ImportError as e:
    import sys
    if 'google.colab' in sys.modules:
       # Install Sionna in Google Colab
       print("Installing Sionna and restarting the runtime. Please run the cell again.")
       os.system("pip install sionna")
       os.kill(os.getpid(), 5)
    else:
       raise e

# Configure the notebook to use only a single GPU and allocate only as much memory as needed
# For more details, see https://www.tensorflow.org/guide/gpu
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)

# Avoid warnings from TensorFlow
tf.get_logger().setLevel('ERROR')

import numpy as np

# For link-level simulations
from sionna.phy.channel import OFDMChannel, CIRDataset
from sionna.phy.nr import PUSCHConfig, PUSCHTransmitter, PUSCHReceiver
from sionna.phy.utils import ebnodb2no, PlotBER
from sionna.phy.ofdm import KBestDetector, LinearDetector
from sionna.phy.mimo import StreamManagement

# Import Sionna RT components
from sionna.rt import load_scene, Camera, Transmitter, Receiver, PlanarArray,\
                      PathSolver, RadioMapSolver

no_preview = False # Toggle to False to use the preview widget
                  # instead of rendering for scene visualization

# %% [markdown]
# # Setting up the Ray Tracer
#
# Let’s start by defining some constants that control the system we want to simulate.

# %%
import json
import numpy as np
import pymap3d as pm

# 將各種數值型別（Tensor/ndarray/drjit 等）安全轉成 Python float
def to_float(v):
    if hasattr(v, "numpy"):          # TensorFlow / PyTorch 等
        v = v.numpy()
    if hasattr(v, "__array__"):
        v = np.asarray(v)
    if hasattr(v, "item"):
        v = v.item()
    return float(v)

def export_tx_to_json(tx, out_path="uav_from_sionna.json"):
    # 1) 你的 OSM 外框（度）
    min_lat = 24.7831
    max_lat = 24.7909
    min_lon = 120.9935
    max_lon = 121.0024

    # 2) 以外框中心當原點
    lat0 = (min_lat + max_lat) / 2.0
    lon0 = (min_lon + max_lon) / 2.0
    h0   = 0.0

    # 3) ENU(公尺) -> 經緯高
    x, y, z = (to_float(c) for c in tx.position)     # e, n, u（公尺）
    lat, lon, h = pm.enu2geodetic(x, y, z, lat0, lon0, h0)
    lat, lon, h = to_float(lat), to_float(lon), to_float(h)

    # 4) 組 JSON 並輸出
    out = {
        "bbox": {
            "min_lat": round(min_lat, 7),
            "max_lat": round(max_lat, 7),
            "min_lon": round(min_lon, 7),
            "max_lon": round(max_lon, 7)
        },
        "origin": {"lat": round(lat0, 7), "lon": round(lon0, 7), "h": float(h0)},
        "transmitter": {
            "name": getattr(tx, "name", "tx"),
            "position_xyz_m": [float(x), float(y), float(z)],
            "geodetic": {"lat": round(lat, 7), "lon": round(lon, 7), "h": round(h, 3)}
        }
    }

    with open(out_path, "w", encoding="utf-8") as f:
        json.dump(out, f, ensure_ascii=False, indent=2)
    print(f"[export] Wrote {out_path}")

# %%
# System parameters
subcarrier_spacing = 30e3 # Hz
num_time_steps = 14 # Total number of ofdm symbols per slot
carrier_frequency = 3.5e9 # Hz

# num_tx = 4 # Number of users
# num_rx = 1 # Only one receiver considered
# num_tx_ant = 4 # Each user has 4 antennas
# num_rx_ant = 16 # The receiver is equipped with 16 antennas

num_tx = 2 # Number of users
num_rx = 1 # Only one receiver considered
num_tx_ant = 1 # Each user has 4 antennas
num_rx_ant = 2 # The receiver is equipped with 16 antennas

# batch_size for CIR generation
# batch_size_cir = 1000
batch_size_cir = 6

# %% [markdown]
# We then set up the radio propagation environment. We start by loading a scene and then add a transmitter that acts as a base station. We will later use channel reciprocity to simulate the uplink direction.

# %%
# Load an integrated scene.
# You can try other scenes, such as `sionna.rt.scene.etoile`. Note that this would require
# updating the position of the transmitter (see below in this cell).
# scene = load_scene(sionna.rt.scene.munich)
scene = load_scene("building_1.xml")
# scene.preview()

# Transmitter (=basestation) has an antenna pattern from 3GPP 38.901
scene.tx_array = PlanarArray(num_rows=1,
                             num_cols=num_rx_ant//2, # We want to transmitter to be equiped with 2 antennas
                             vertical_spacing=0.5,
                             horizontal_spacing=0.5,
                             pattern="tr38901",
                             polarization="cross")

# Create transmitter
tx1 = Transmitter(name="tx1",
                 position=[30,46,50],
                 look_at=[30,0,10], # optional, defines view direction
                 power_dbm=23,
                 display_radius=3.) # optinal, radius of the sphere for visualizing the device

tx2 = Transmitter(name="tx2",
                 position=[30,46,22],
                 look_at=[30,0,10], # optional, defines view direction
                 power_dbm=23,
                 display_radius=3.) # optinal, radius of the sphere for visualizing the device

# scene.preview()

scene.add(tx1)
export_tx_to_json(tx1)

scene.add(tx2)

# Create new camera
bird_cam = Camera(position=[0,80,500], orientation=np.array([0,np.pi/2,-np.pi/2]))
# Out:
# [export] Wrote uav_from_sionna.json

# %%
# for testing fly
import time
start_pos = [30, 46, 50]
end_pos   = [60, 20, 50]
steps = 300  # 飛行過程共分為多少步
interval_sec = 0.01  # 每次輸出間隔秒數

for i in range(steps + 1):
    # 線性插值新位置
    alpha = i / steps
    new_pos = [
        (1 - alpha) * start_pos[0] + alpha * end_pos[0],
        (1 - alpha) * start_pos[1] + alpha * end_pos[1],
        (1 - alpha) * start_pos[2] + alpha * end_pos[2],
    ]
    tx1.position = new_pos

    export_tx_to_json(tx1, "uav_from_sionna.json")
    print(f"[step {i}/{steps}] tx1 @ {new_pos}")

    time.sleep(interval_sec)
# Out:
# [export] Wrote uav_from_sionna.json
# [step 0/300] tx1 @ [30.0, 46.0, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 1/300] tx1 @ [30.1, 45.91333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 2/300] tx1 @ [30.199999999999996, 45.82666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 3/300] tx1 @ [30.3, 45.74, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 4/300] tx1 @ [30.400000000000002, 45.653333333333336, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 5/300] tx1 @ [30.5, 45.56666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 6/300] tx1 @ [30.599999999999998, 45.48, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 7/300] tx1 @ [30.7, 45.39333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 8/300] tx1 @ [30.800000000000004, 45.306666666666665, 50.00000000000001]
# [export] Wrote uav_from_sionna.json
# [step 9/300] tx1 @ [30.9, 45.22, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 10/300] tx1 @ [31.0, 45.13333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 11/300] tx1 @ [31.1, 45.04666666666667, 50.00000000000001]
# [export] Wrote uav_from_sionna.json
# [step 12/300] tx1 @ [31.199999999999996, 44.959999999999994, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 13/300] tx1 @ [31.3, 44.873333333333335, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 14/300] tx1 @ [31.400000000000002, 44.78666666666666, 50.00000000000001]
# [export] Wrote uav_from_sionna.json
# [step 15/300] tx1 @ [31.5, 44.699999999999996, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 16/300] tx1 @ [31.599999999999998, 44.61333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 17/300] tx1 @ [31.7, 44.526666666666664, 50.00000000000001]
# [export] Wrote uav_from_sionna.json
# [step 18/300] tx1 @ [31.799999999999997, 44.44, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 19/300] tx1 @ [31.9, 44.35333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 20/300] tx1 @ [32.0, 44.26666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 21/300] tx1 @ [32.1, 44.17999999999999, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 22/300] tx1 @ [32.2, 44.093333333333334, 49.99999999999999]
# [export] Wrote uav_from_sionna.json
# [step 23/300] tx1 @ [32.3, 44.00666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 24/300] tx1 @ [32.4, 43.92, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 25/300] tx1 @ [32.5, 43.83333333333333, 49.99999999999999]
# [export] Wrote uav_from_sionna.json
# [step 26/300] tx1 @ [32.6, 43.74666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 27/300] tx1 @ [32.7, 43.66, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 28/300] tx1 @ [32.8, 43.57333333333333, 49.99999999999999]
# [export] Wrote uav_from_sionna.json
# [step 29/300] tx1 @ [32.9, 43.486666666666665, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 30/300] tx1 @ [33.0, 43.4, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 31/300] tx1 @ [33.1, 43.31333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 32/300] tx1 @ [33.2, 43.22666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 33/300] tx1 @ [33.3, 43.14, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 34/300] tx1 @ [33.4, 43.053333333333335, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 35/300] tx1 @ [33.5, 42.96666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 36/300] tx1 @ [33.599999999999994, 42.879999999999995, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 37/300] tx1 @ [33.7, 42.79333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 38/300] tx1 @ [33.8, 42.70666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 39/300] tx1 @ [33.900000000000006, 42.620000000000005, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 40/300] tx1 @ [34.0, 42.53333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 41/300] tx1 @ [34.099999999999994, 42.446666666666665, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 42/300] tx1 @ [34.2, 42.36, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 43/300] tx1 @ [34.3, 42.27333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 44/300] tx1 @ [34.4, 42.18666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 45/300] tx1 @ [34.5, 42.1, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 46/300] tx1 @ [34.599999999999994, 42.013333333333335, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 47/300] tx1 @ [34.699999999999996, 41.92666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 48/300] tx1 @ [34.8, 41.84, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 49/300] tx1 @ [34.900000000000006, 41.75333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 50/300] tx1 @ [35.0, 41.66666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 51/300] tx1 @ [35.1, 41.58, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 52/300] tx1 @ [35.2, 41.49333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 53/300] tx1 @ [35.3, 41.406666666666666, 50.00000000000001]
# [export] Wrote uav_from_sionna.json
# [step 54/300] tx1 @ [35.4, 41.32000000000001, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 55/300] tx1 @ [35.5, 41.23333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 56/300] tx1 @ [35.6, 41.14666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 57/300] tx1 @ [35.7, 41.06, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 58/300] tx1 @ [35.8, 40.973333333333336, 49.99999999999999]
# [export] Wrote uav_from_sionna.json
# [step 59/300] tx1 @ [35.9, 40.88666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 60/300] tx1 @ [36.0, 40.800000000000004, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 61/300] tx1 @ [36.1, 40.71333333333334, 49.99999999999999]
# [export] Wrote uav_from_sionna.json
# [step 62/300] tx1 @ [36.2, 40.626666666666665, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 63/300] tx1 @ [36.300000000000004, 40.540000000000006, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 64/300] tx1 @ [36.4, 40.45333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 65/300] tx1 @ [36.5, 40.36666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 66/300] tx1 @ [36.6, 40.28, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 67/300] tx1 @ [36.699999999999996, 40.193333333333335, 49.99999999999999]
# [export] Wrote uav_from_sionna.json
# [step 68/300] tx1 @ [36.8, 40.10666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 69/300] tx1 @ [36.900000000000006, 40.02, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 70/300] tx1 @ [37.0, 39.93333333333333, 49.99999999999999]
# [export] Wrote uav_from_sionna.json
# [step 71/300] tx1 @ [37.099999999999994, 39.846666666666664, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 72/300] tx1 @ [37.2, 39.76, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 73/300] tx1 @ [37.3, 39.67333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 74/300] tx1 @ [37.4, 39.58666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 75/300] tx1 @ [37.5, 39.5, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 76/300] tx1 @ [37.6, 39.413333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 77/300] tx1 @ [37.7, 39.32666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 78/300] tx1 @ [37.8, 39.24, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 79/300] tx1 @ [37.9, 39.153333333333336, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 80/300] tx1 @ [38.0, 39.06666666666667, 50.00000000000001]
# [export] Wrote uav_from_sionna.json
# [step 81/300] tx1 @ [38.1, 38.98, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 82/300] tx1 @ [38.2, 38.89333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 83/300] tx1 @ [38.300000000000004, 38.806666666666665, 50.00000000000001]
# [export] Wrote uav_from_sionna.json
# [step 84/300] tx1 @ [38.4, 38.72, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 85/300] tx1 @ [38.5, 38.63333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 86/300] tx1 @ [38.6, 38.54666666666667, 50.00000000000001]
# [export] Wrote uav_from_sionna.json
# [step 87/300] tx1 @ [38.699999999999996, 38.459999999999994, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 88/300] tx1 @ [38.8, 38.373333333333335, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 89/300] tx1 @ [38.900000000000006, 38.28666666666666, 50.00000000000001]
# [export] Wrote uav_from_sionna.json
# [step 90/300] tx1 @ [39.0, 38.199999999999996, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 91/300] tx1 @ [39.099999999999994, 38.11333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 92/300] tx1 @ [39.2, 38.02666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 93/300] tx1 @ [39.3, 37.94, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 94/300] tx1 @ [39.4, 37.85333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 95/300] tx1 @ [39.5, 37.766666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 96/300] tx1 @ [39.599999999999994, 37.68, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 97/300] tx1 @ [39.7, 37.59333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 98/300] tx1 @ [39.8, 37.50666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 99/300] tx1 @ [39.9, 37.419999999999995, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 100/300] tx1 @ [40.0, 37.333333333333336, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 101/300] tx1 @ [40.099999999999994, 37.24666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 102/300] tx1 @ [40.2, 37.16, 49.99999999999999]
# [export] Wrote uav_from_sionna.json
# [step 103/300] tx1 @ [40.3, 37.07333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 104/300] tx1 @ [40.400000000000006, 36.986666666666665, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 105/300] tx1 @ [40.5, 36.900000000000006, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 106/300] tx1 @ [40.6, 36.81333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 107/300] tx1 @ [40.7, 36.72666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 108/300] tx1 @ [40.8, 36.64, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 109/300] tx1 @ [40.900000000000006, 36.553333333333335, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 110/300] tx1 @ [41.0, 36.46666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 111/300] tx1 @ [41.099999999999994, 36.38, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 112/300] tx1 @ [41.2, 36.29333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 113/300] tx1 @ [41.3, 36.20666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 114/300] tx1 @ [41.400000000000006, 36.12, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 115/300] tx1 @ [41.5, 36.03333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 116/300] tx1 @ [41.599999999999994, 35.946666666666665, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 117/300] tx1 @ [41.7, 35.86, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 118/300] tx1 @ [41.8, 35.77333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 119/300] tx1 @ [41.9, 35.68666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 120/300] tx1 @ [42.0, 35.599999999999994, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 121/300] tx1 @ [42.099999999999994, 35.513333333333335, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 122/300] tx1 @ [42.2, 35.42666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 123/300] tx1 @ [42.3, 35.34, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 124/300] tx1 @ [42.400000000000006, 35.25333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 125/300] tx1 @ [42.5, 35.166666666666664, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 126/300] tx1 @ [42.6, 35.080000000000005, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 127/300] tx1 @ [42.7, 34.99333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 128/300] tx1 @ [42.8, 34.90666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 129/300] tx1 @ [42.900000000000006, 34.82, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 130/300] tx1 @ [43.0, 34.733333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 131/300] tx1 @ [43.1, 34.64666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 132/300] tx1 @ [43.2, 34.56, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 133/300] tx1 @ [43.3, 34.47333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 134/300] tx1 @ [43.400000000000006, 34.38666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 135/300] tx1 @ [43.5, 34.3, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 136/300] tx1 @ [43.599999999999994, 34.21333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 137/300] tx1 @ [43.7, 34.126666666666665, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 138/300] tx1 @ [43.800000000000004, 34.040000000000006, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 139/300] tx1 @ [43.9, 33.95333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 140/300] tx1 @ [44.0, 33.86666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 141/300] tx1 @ [44.1, 33.78, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 142/300] tx1 @ [44.199999999999996, 33.69333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 143/300] tx1 @ [44.3, 33.60666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 144/300] tx1 @ [44.4, 33.52, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 145/300] tx1 @ [44.5, 33.43333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 146/300] tx1 @ [44.6, 33.346666666666664, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 147/300] tx1 @ [44.7, 33.260000000000005, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 148/300] tx1 @ [44.8, 33.17333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 149/300] tx1 @ [44.9, 33.08666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 150/300] tx1 @ [45.0, 33.0, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 151/300] tx1 @ [45.1, 32.913333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 152/300] tx1 @ [45.2, 32.82666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 153/300] tx1 @ [45.3, 32.739999999999995, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 154/300] tx1 @ [45.4, 32.653333333333336, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 155/300] tx1 @ [45.5, 32.56666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 156/300] tx1 @ [45.6, 32.48, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 157/300] tx1 @ [45.7, 32.39333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 158/300] tx1 @ [45.8, 32.30666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 159/300] tx1 @ [45.9, 32.22, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 160/300] tx1 @ [46.0, 32.13333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 161/300] tx1 @ [46.099999999999994, 32.04666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 162/300] tx1 @ [46.2, 31.959999999999997, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 163/300] tx1 @ [46.3, 31.873333333333335, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 164/300] tx1 @ [46.4, 31.78666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 165/300] tx1 @ [46.5, 31.7, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 166/300] tx1 @ [46.6, 31.613333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 167/300] tx1 @ [46.7, 31.526666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 168/300] tx1 @ [46.8, 31.439999999999998, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 169/300] tx1 @ [46.900000000000006, 31.35333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 170/300] tx1 @ [47.0, 31.266666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 171/300] tx1 @ [47.099999999999994, 31.18, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 172/300] tx1 @ [47.199999999999996, 31.093333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 173/300] tx1 @ [47.3, 31.006666666666668, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 174/300] tx1 @ [47.4, 30.92, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 175/300] tx1 @ [47.5, 30.833333333333332, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 176/300] tx1 @ [47.6, 30.746666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 177/300] tx1 @ [47.7, 30.660000000000004, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 178/300] tx1 @ [47.8, 30.57333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 179/300] tx1 @ [47.9, 30.486666666666668, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 180/300] tx1 @ [48.0, 30.400000000000002, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 181/300] tx1 @ [48.1, 30.313333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 182/300] tx1 @ [48.199999999999996, 30.226666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 183/300] tx1 @ [48.300000000000004, 30.14, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 184/300] tx1 @ [48.4, 30.053333333333335, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 185/300] tx1 @ [48.5, 29.96666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 186/300] tx1 @ [48.6, 29.880000000000003, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 187/300] tx1 @ [48.7, 29.793333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 188/300] tx1 @ [48.8, 29.706666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 189/300] tx1 @ [48.9, 29.619999999999997, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 190/300] tx1 @ [49.0, 29.53333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 191/300] tx1 @ [49.1, 29.446666666666665, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 192/300] tx1 @ [49.199999999999996, 29.36, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 193/300] tx1 @ [49.300000000000004, 29.273333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 194/300] tx1 @ [49.4, 29.186666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 195/300] tx1 @ [49.5, 29.099999999999998, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 196/300] tx1 @ [49.6, 29.013333333333335, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 197/300] tx1 @ [49.7, 28.92666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 198/300] tx1 @ [49.8, 28.84, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 199/300] tx1 @ [49.9, 28.75333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 200/300] tx1 @ [50.0, 28.666666666666668, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 201/300] tx1 @ [50.1, 28.58, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 202/300] tx1 @ [50.2, 28.493333333333332, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 203/300] tx1 @ [50.300000000000004, 28.406666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 204/300] tx1 @ [50.400000000000006, 28.32, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 205/300] tx1 @ [50.5, 28.233333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 206/300] tx1 @ [50.599999999999994, 28.14666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 207/300] tx1 @ [50.7, 28.060000000000002, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 208/300] tx1 @ [50.8, 27.973333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 209/300] tx1 @ [50.9, 27.886666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 210/300] tx1 @ [51.0, 27.800000000000004, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 211/300] tx1 @ [51.1, 27.71333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 212/300] tx1 @ [51.2, 27.626666666666665, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 213/300] tx1 @ [51.3, 27.54, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 214/300] tx1 @ [51.400000000000006, 27.453333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 215/300] tx1 @ [51.5, 27.366666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 216/300] tx1 @ [51.599999999999994, 27.28, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 217/300] tx1 @ [51.7, 27.193333333333335, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 218/300] tx1 @ [51.8, 27.106666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 219/300] tx1 @ [51.9, 27.020000000000003, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 220/300] tx1 @ [52.0, 26.933333333333337, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 221/300] tx1 @ [52.1, 26.846666666666664, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 222/300] tx1 @ [52.2, 26.76, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 223/300] tx1 @ [52.3, 26.673333333333332, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 224/300] tx1 @ [52.400000000000006, 26.586666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 225/300] tx1 @ [52.5, 26.5, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 226/300] tx1 @ [52.599999999999994, 26.413333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 227/300] tx1 @ [52.7, 26.326666666666668, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 228/300] tx1 @ [52.8, 26.24, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 229/300] tx1 @ [52.9, 26.153333333333336, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 230/300] tx1 @ [53.0, 26.066666666666663, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 231/300] tx1 @ [53.1, 25.979999999999997, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 232/300] tx1 @ [53.2, 25.893333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 233/300] tx1 @ [53.3, 25.806666666666665, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 234/300] tx1 @ [53.400000000000006, 25.72, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 235/300] tx1 @ [53.5, 25.633333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 236/300] tx1 @ [53.599999999999994, 25.546666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 237/300] tx1 @ [53.7, 25.46, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 238/300] tx1 @ [53.800000000000004, 25.373333333333335, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 239/300] tx1 @ [53.9, 25.28666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 240/300] tx1 @ [54.0, 25.199999999999996, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 241/300] tx1 @ [54.1, 25.113333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 242/300] tx1 @ [54.2, 25.026666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 243/300] tx1 @ [54.3, 24.94, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 244/300] tx1 @ [54.400000000000006, 24.85333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 245/300] tx1 @ [54.5, 24.766666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 246/300] tx1 @ [54.599999999999994, 24.68, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 247/300] tx1 @ [54.699999999999996, 24.593333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 248/300] tx1 @ [54.800000000000004, 24.506666666666664, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 249/300] tx1 @ [54.9, 24.42, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 250/300] tx1 @ [55.0, 24.333333333333332, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 251/300] tx1 @ [55.1, 24.24666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 252/300] tx1 @ [55.2, 24.160000000000004, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 253/300] tx1 @ [55.3, 24.07333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 254/300] tx1 @ [55.4, 23.986666666666665, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 255/300] tx1 @ [55.5, 23.900000000000002, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 256/300] tx1 @ [55.6, 23.813333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 257/300] tx1 @ [55.699999999999996, 23.726666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 258/300] tx1 @ [55.800000000000004, 23.64, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 259/300] tx1 @ [55.9, 23.553333333333335, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 260/300] tx1 @ [56.0, 23.46666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 261/300] tx1 @ [56.1, 23.38, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 262/300] tx1 @ [56.2, 23.293333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 263/300] tx1 @ [56.3, 23.206666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 264/300] tx1 @ [56.4, 23.12, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 265/300] tx1 @ [56.5, 23.03333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 266/300] tx1 @ [56.6, 22.946666666666665, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 267/300] tx1 @ [56.699999999999996, 22.86, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 268/300] tx1 @ [56.800000000000004, 22.773333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 269/300] tx1 @ [56.9, 22.686666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 270/300] tx1 @ [57.0, 22.599999999999998, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 271/300] tx1 @ [57.1, 22.513333333333335, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 272/300] tx1 @ [57.2, 22.42666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 273/300] tx1 @ [57.3, 22.339999999999996, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 274/300] tx1 @ [57.4, 22.253333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 275/300] tx1 @ [57.5, 22.166666666666668, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 276/300] tx1 @ [57.6, 22.08, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 277/300] tx1 @ [57.699999999999996, 21.993333333333336, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 278/300] tx1 @ [57.800000000000004, 21.906666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 279/300] tx1 @ [57.900000000000006, 21.82, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 280/300] tx1 @ [58.0, 21.733333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 281/300] tx1 @ [58.099999999999994, 21.64666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 282/300] tx1 @ [58.2, 21.56, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 283/300] tx1 @ [58.3, 21.473333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 284/300] tx1 @ [58.4, 21.386666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 285/300] tx1 @ [58.5, 21.3, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 286/300] tx1 @ [58.6, 21.21333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 287/300] tx1 @ [58.699999999999996, 21.126666666666665, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 288/300] tx1 @ [58.8, 21.04, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 289/300] tx1 @ [58.900000000000006, 20.95333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 290/300] tx1 @ [59.0, 20.866666666666664, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 291/300] tx1 @ [59.099999999999994, 20.78, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 292/300] tx1 @ [59.2, 20.69333333333333, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 293/300] tx1 @ [59.300000000000004, 20.60666666666667, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 294/300] tx1 @ [59.4, 20.520000000000003, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 295/300] tx1 @ [59.5, 20.433333333333334, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 296/300] tx1 @ [59.6, 20.346666666666668, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 297/300] tx1 @ [59.699999999999996, 20.26, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 298/300] tx1 @ [59.8, 20.173333333333336, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 299/300] tx1 @ [59.900000000000006, 20.086666666666666, 50.0]
# [export] Wrote uav_from_sionna.json
# [step 300/300] tx1 @ [60.0, 20.0, 50.0]

# %% [markdown]
# We then compute a radio map for the instantiated transmitter.

# %%
# max_depth = 5
max_depth = 12

# Radio map solver
rm_solver = RadioMapSolver()

# Compute the radio map
rm = rm_solver(scene,
               max_depth=12,
               cell_size=(1., 1.),
               samples_per_tx=10**7)

# %% [markdown]
# Let’s visualize the computed radio map.

# %%
if no_preview:
    # Render an image
    scene.render(camera=bird_cam,
                 radio_map=rm,
                 rm_vmin=-110,
                 clip_at=12.); # Clip the scene at rendering for visualizing the refracted field
else:
    # Show preview
    scene.preview(radio_map=rm,
                  rm_vmin=-110,
                  clip_at=40.); # Clip the scene at rendering for visualizing the refracted field
# Out:
# HBox(children=(Renderer(camera=PerspectiveCamera(aspect=1.31, children=(DirectionalLight(intensity=0.25, posit…

# %% [markdown]
# The function RadioMap.sample_positions() allows sampling of random user positions from a radio map. It ensures that only positions that have a path gain of at least min_gain_dB dB and at most max_gain_dB dB are sampled, i.e., it ignores positions without a connection to the transmitter. Further, one can set the distances min_dist and max_dist to sample only points within a certain distance range from the transmitter.

# %%
min_gain_db = -130 # in dB; ignore any position with less than -130 dB path gain
max_gain_db = 0 # in dB; ignore strong paths

# Sample points in a 5-400m range around the receiver
min_dist = 5 # in m
max_dist = 400 # in m

# Sample batch_size random user positions from the radio map
# ue_pos, _ = rm.sample_positions(num_pos=batch_size_cir,
#                                 metric="path_gain",
#                                 min_val_db=min_gain_db,
#                                 max_val_db=max_gain_db,
#                                 min_dist=min_dist,
#                                 max_dist=max_dist)

ue_pos = [[20,0,1.5], [30,0,1.5], [20,10,1.5], [30,10,1.5], [20,-10,1.5], [30,-10,1.5]]

# %% [markdown]
# We now add new receivers (=UEs) at the sampled positions.
#
# Remark: This is an example for 5G NR PUSCH (uplink direction), we will reverse the direction of the channel for later BER simulations.

# %%
# Configure antenna array for all receivers (=UEs)
# scene.rx_array = PlanarArray(num_rows=1,
#                              num_cols=num_tx_ant//2, # Each receiver is equipped with 4 antennas
#                              vertical_spacing=0.5,
#                              horizontal_spacing=0.5,
#                              pattern="iso",
#                              polarization="cross")

scene.rx_array = PlanarArray(num_rows=1,
                             num_cols=num_tx_ant, # Each receiver is equipped with 1 antennas
                             vertical_spacing=0.5,
                             horizontal_spacing=0.5,
                             pattern="iso",
                             polarization="V")
print(type(ue_pos))
print(len(ue_pos))       # 最外層長度
print(len(ue_pos[0]))    # ue_pos[0] 長度
print(ue_pos[:5])        # 看前五個值

# Create batch_size receivers
for i in range(batch_size_cir):
    scene.remove(f"rx-{i}") # Remove old receiver if any
    rx = Receiver(name=f"rx-{i}",
                  position=ue_pos[i], # Position sampled from radio map
                  velocity=(3.,3.,0),
                  display_radius=3., # optional, radius of the sphere for visualizing the device
                  color=(0,1,0) # optional, color for visualizing the device
                  )
    scene.add(rx)
p_solver = PathSolver()
paths = p_solver(scene, max_depth=5)

if no_preview:
    # Render an image
    scene.render(camera=bird_cam,
                 radio_map=rm,
                 rm_vmin=-110,
                 clip_at=12.); # Clip the scene at rendering for visualizing the refracted field
else:
    # Show preview
    scene.preview(radio_map=rm,
                  rm_vmin=-110,
                  clip_at=40.); # Clip the scene at rendering for visualizing the refracted field
# Out:
# <class 'list'>
# 6
# 3
# [[20, 0, 1.5], [30, 0, 1.5], [20, 10, 1.5], [30, 10, 1.5], [20, -10, 1.5]]
# HBox(children=(Renderer(camera=PerspectiveCamera(aspect=1.31, children=(DirectionalLight(intensity=0.25, matri…

# %% [markdown]
# Each dot represents a receiver position drawn from the random sampling function of the radio map. This allows to efficiently sample batches of random channel realizations even in complex scenarios.

# %% [markdown]
# # Creating a CIR Dataset
#
# We can now simulate the CIRs for many different positions which will be used later on as a dataset for link-level simulations.
#
# Remark: Running the cells below can take some time depending on the requested number of CIRs.

# %%
# target_num_cirs = 5000 # Defines how many different CIRs are generated.
target_num_cirs = 2 # Defines how many different CIRs are generated.
# Remark: some path are removed if no path was found for this position

max_depth = 5
min_gain_db = -130 # in dB / ignore any position with less than -130 dB path gain
max_gain_db = 0 # in dB / ignore any position with more than 0 dB path gain

# Sample points within a 10-400m radius around the transmitter
min_dist = 10 # in m
max_dist = 400 # in m

# List of channel impulse reponses
a_list = []
tau_list = []

# Maximum number of paths over all batches of CIRs.
# This is used later to concatenate all CIRs.
max_num_paths = 0

# Path solver
p_solver = PathSolver()

# Each simulation returns batch_size_cir results
num_runs = int(np.ceil(target_num_cirs/batch_size_cir))
for idx in range(num_runs):
    print(f"Progress: {idx+1}/{num_runs}", end="\r")

    # Sample random user positions
    # ue_pos, _ = rm.sample_positions(
    #                     num_pos=batch_size_cir,
    #                     metric="path_gain",
    #                     min_val_db=min_gain_db,
    #                     max_val_db=max_gain_db,
    #                     min_dist=min_dist,
    #                     max_dist=max_dist,
    #                     seed=idx) # Change the seed from one run to the next to avoid sampling the same positions

    ue_pos = [[[30,0,1.5], [20,0,1.5]]]
    
    # Update all receiver positions
    for rx in range(batch_size_cir):
        scene.receivers[f"rx-{rx}"].position = ue_pos[rx]

    # Simulate CIR
    paths = p_solver(scene, max_depth=max_depth, max_num_paths_per_src=10**7)

    # Transform paths into channel impulse responses
    a, tau = paths.cir(sampling_frequency=subcarrier_spacing,
                         num_time_steps=14,
                         out_type='numpy')
    
    a_list.append(a)
    tau_list.append(tau)

    # Update maximum number of paths over all batches of CIRs
    num_paths = a.shape[-2]
    if num_paths > max_num_paths:
        max_num_paths = num_paths

# Show path
if no_preview:
    # Render an image
    scene.render(camera=bird_cam,
                 radio_map=rm,
                 rm_vmin=-110,
                 paths=paths,
                 clip_at=12.); # Clip the scene at rendering for visualizing the refracted field
else:
    # Show preview
    scene.preview(radio_map=rm,
                  rm_vmin=-110,
                  paths=paths,
                  clip_at=40.); # Clip the scene at rendering for visualizing the refracted field


# Concatenate all the CIRs into a single tensor along the num_rx dimension.
# First, we need to pad the CIRs to ensure they all have the same number of paths.
a = []
tau = []
for a_,tau_ in zip(a_list, tau_list):
    num_paths = a_.shape[-2]
    a.append(np.pad(a_, [[0,0],[0,0],[0,0],[0,0],[0,max_num_paths-num_paths],[0,0]], constant_values=0))
    tau.append(np.pad(tau_, [[0,0],[0,0],[0,max_num_paths-num_paths]], constant_values=0))
a = np.concatenate(a, axis=0) # Concatenate along the num_rx dimension
tau = np.concatenate(tau, axis=0)

# Let's now convert to uplink direction, by switing the receiver and transmitter
# dimensions
a = np.transpose(a, (2,3,0,1,4,5))
tau = np.transpose(tau, (1,0,2))

# Add a batch_size dimension
a = np.expand_dims(a, axis=0)
tau = np.expand_dims(tau, axis=0)

# Exchange the num_tx and batchsize dimensions
a = np.transpose(a, [3, 1, 2, 0, 4, 5, 6])
tau = np.transpose(tau, [2, 1, 0, 3])

# Remove CIRs that have no active link (i.e., a is all-zero)
p_link = np.sum(np.abs(a)**2, axis=(1,2,3,4,5,6))
a = a[p_link>0.,...]
tau = tau[p_link>0.,...]

print("Shape of a:", a.shape)
print("Shape of tau: ", tau.shape)

np.savez("cir_nycu_2RU_2UE.npz", a=a, tau=tau)
# Out:
# Progress: 1/1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 43
#      41 # Update all receiver positions
#      42 for rx in range(batch_size_cir):
# ---> 43     scene.receivers[f"rx-{rx}"].position = ue_pos[rx]
#      45 # Simulate CIR
#      46 paths = p_solver(scene, max_depth=max_depth, max_num_paths_per_src=10**7)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sionna\rt\radio_devices\radio_device.py:93, in RadioDevice.position(self, v)
#      91 @position.setter
#      92 def position(self, v):
# ---> 93     self._position = mi.Point3f(v)
#
# TypeError: mitsuba.Point3f.__init__(): Input has the wrong size (expected 3 elements, got 2).

# %% [markdown]
# Note that transmitters and receivers have been reversed, i.e., the transmitter now denotes the UE (with 4 antennas each) and the receiver is the base station (with 16 antennas).
#
# Remark: We have removed all positions for which the resulting CIR had zero gain, i.e., there was no path between the transmitter and the receiver. This comes from the fact that the RadioMap.sample_positions() function samples from a radio map subdivided into cells and randomizes the position within the cells. Therefore, randomly sampled positions may have no paths connecting them to the transmitter.
#
# Let us now define a data generator that samples random UEs from the dataset and yields the previously simulated CIRs.

# %%
class CIRGenerator:
    """Creates a generator from a given dataset of channel impulse responses

    The generator samples ``num_tx`` different transmitters from the given path
    coefficients `a` and path delays `tau` and stacks the CIRs into a single tensor.

    Note that the generator internally samples ``num_tx`` random transmitters
    from the dataset. For this, the inputs ``a`` and ``tau`` must be given for
    a single transmitter (i.e., ``num_tx`` =1) which will then be stacked
    internally.

    Parameters
    ----------
    a : [batch size, num_rx, num_rx_ant, 1, num_tx_ant, num_paths, num_time_steps], complex
        Path coefficients per transmitter

    tau : [batch size, num_rx, 1, num_paths], float
        Path delays [s] per transmitter

    num_tx : int
        Number of transmitters

    Output
    -------
    a : [batch size, num_rx, num_rx_ant, num_tx, num_tx_ant, num_paths, num_time_steps], tf.complex
        Path coefficients

    tau : [batch size, num_rx, num_tx, num_paths], tf.float
        Path delays [s]
    """

    def __init__(self,
                 a,
                 tau,
                 num_tx):

        # Copy to tensorflow
        self._a = tf.constant(a, tf.complex64)
        self._tau = tf.constant(tau, tf.float32)
        self._dataset_size = self._a.shape[0]

        self._num_tx = num_tx

    def __call__(self):

        # Generator implements an infinite loop that yields new random samples
        while True:
            # Sample 4 random users and stack them together
            idx,_,_ = tf.random.uniform_candidate_sampler(
                            tf.expand_dims(tf.range(self._dataset_size, dtype=tf.int64), axis=0),
                            num_true=self._dataset_size,
                            num_sampled=self._num_tx,
                            unique=True,
                            range_max=self._dataset_size)

            a = tf.gather(self._a, idx)
            tau = tf.gather(self._tau, idx)

            # Transpose to remove batch dimension
            a = tf.transpose(a, (3,1,2,0,4,5,6))
            tau = tf.transpose(tau, (2,1,0,3))

            # And remove batch-dimension
            a = tf.squeeze(a, axis=0)
            tau = tf.squeeze(tau, axis=0)

            yield a, tau

# %% [markdown]
# We use Sionna’s built-in CIRDataset to initialize a channel model that can be directly used in Sionna’s OFDMChannel layer.

# %%
batch_size = 20 # Must be the same for the BER simulations as CIRDataset returns fixed batch_size

# Init CIR generator
cir_generator = CIRGenerator(a,
                             tau,
                             num_tx)
# Initialises a channel model that can be directly used by OFDMChannel layer
channel_model = CIRDataset(cir_generator,
                           batch_size,
                           num_rx,
                           num_rx_ant,
                           num_tx,
                           num_tx_ant,
                           max_num_paths,
                           num_time_steps)
